# %%
from ultralytics import YOLO
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="6UpzhOjTAFEsOb95iyX1")
project = rf.workspace("hafis-muhammed").project("license-plate-recognition-rxg4e-imsga")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to License-Plate-Recognition-1 in yolov8:: 100%|██████████| 20255/20255 [00:12<00:00, 1680.70it/s]

# %%
# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# %%
result = model.train(data='License-Plate-Recognition-1\data.yaml',epochs = 100, device="cuda")
# Out:
# invalid escape sequence '\d'
# invalid escape sequence '\d'
# invalid escape sequence '\d'
# Ultralytics 8.4.53  Python-3.12.13 torch-2.12.0+cu132 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...
